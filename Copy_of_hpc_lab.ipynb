# %% [markdown]
# <a href="https://colab.research.google.com/github/maniminnu/DAA/blob/main/Copy_of_hpc_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello hpc lab")
# Out:
# hello hpc lab
